# %%
import sys
print(sys.executable)
# !{sys.executable} -m pip --version
# Out:
# /Users/matt/@mattduffy/calories-py/bin/python3
# pip 26.0 from /Users/matt/@mattduffy/calories-py/lib/python3.14/site-packages/pip (python 3.14)

# %%
# install hatch for building package
# !{sys.executable} -m pip install hatch

# %%
# install twine for uploading build artifacts to pypi
# !{sys.executable} -m pip install twine

# %%
# !{sys.executable} -m pip install pypistats
# import pypistats
# json_data = pypistats.recent("calories-py", format="json")
# print(json_data)
